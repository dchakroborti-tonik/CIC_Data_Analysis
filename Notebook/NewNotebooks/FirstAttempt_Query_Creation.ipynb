# %%
# %% [markdown]
# # Jupyter Notebook Loading Header
#
# This is a custom loading header for Jupyter Notebooks in Visual Studio Code.
# It includes common imports and settings to get you started quickly.

# %% [markdown]
## Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.cloud import bigquery
import os
path = r'C:\Users\DwaipayanChakroborti\AppData\Roaming\gcloud\legacy_credentials\dchakroborti@tonikbank.com\adc.json'
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = path
client = bigquery.Client(project='prj-prod-dataplatform')

# %% [markdown]
## Configure Settings
# Set options or configurations as needed
# Example: pd.set_option('display.max_columns', None)

# %%
sq = "Select *  from  prj-prod-dataplatform.risk_credit_cic_data.granted_contracts limit 100;"
dfgranted = client.query(sq).to_dataframe(progress_bar_type = 'tqdm')

sq = "Select *  from  prj-prod-dataplatform.risk_credit_cic_data.notgranted_contracts limit 100;"
dfnongranted = client.query(sq).to_dataframe(progress_bar_type = 'tqdm')
# Out:
# Job ID 21174ad0-3af9-49d5-be82-19797cfdc112 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|
# Job ID c6aa2e66-b01d-483b-b559-14332d4722d0 successfully executed: 100%|██████████|
# Downloading: 100%|██████████|

# %%
dfgranted.columns
# Out:
# Index(['digitalLoanAccountId', 'crifApplicationId', 'customerId',
#        'processEngineGuid', 'requestGuid', 'ContractHistoryType',
#        'CBContractCode', 'ContractEndDate', 'ContractPhase',
#        'ContractPhaseDesc', 'ContractStartDate', 'ContractStatus',
#        'ContractStatusDesc', 'ContractType', 'ContractTypeDesc', 'Currency',
#        'CurrencyDesc', 'LastUpdateDate', 'OriginalCurrency',
#        'OriginalCurrencyDesc', 'ProviderCodeEncrypted', 'ProviderContractNo',
#        'ReferenceNo', 'Role', 'RoleDesc', 'BilledAmount',
#        'BoardResolutionFlag', 'BoardResolutionFlagDesc', 'CancellationDate',
#        'CardReferenceCode', 'ChargedAmount', 'CreditLimit', 'CreditPurpose',
#        'CreditPurposeDesc', 'FinancedAmount', 'FirstPaymentDate',
#        'FlagCardUsed', 'HolderLiability', 'HolderLiabilityDesc',
#        'InstallmentType', 'InstallmentTypeDesc', 'InstallmentsNumber',
#        'LastChargeDate', 'LastPaymentAmount', 'LastPaymentDate',
# ...

# %%
dfnongranted.columns
# Out:
# Index(['digitalLoanAccountId', 'crifApplicationId', 'customerId',
#        'processEngineGuid', 'requestGuid', 'CBContractCode',
#        'ContractTypeDesc', 'ContractRequestDate', 'LastUpdateDate',
#        'ProviderCodeEncrypted', 'Role', 'ReferenceNo', 'ContractPhase',
#        'ContractType', 'ProviderContractNo', 'ContractPhaseDesc', 'RoleDesc',
#        'CreditLimit', 'FinancedAmount', 'InstallmentsNumber',
#        'MonthlyPaymentAmount', 'PaymentPeriodicity', 'PaymentPeriodicityDesc',
#        'LinkedSubject_CBSubjectCode', 'LinkedSubject_Name',
#        'LinkedSubject_Role', 'LinkedSubject_RoleDesc', 'Note_TypeDesc',
#        'Note_Text', 'Note_Type', 'run_date'],
#       dtype='object')

# %%
sq = """with base as 
(
-- Query for dfgranted
SELECT
  digitalLoanAccountId,
  crifApplicationId,
  customerId,
  processEngineGuid,
  requestGuid,
  ContractHistoryType,
  CBContractCode,
  ContractEndDate,
  ContractPhase,
  ContractPhaseDesc,
  ContractStartDate,
  ContractStatus,
  ContractStatusDesc,
  ContractType,
  ContractTypeDesc,
  Currency,
  CurrencyDesc,
  LastUpdateDate,
  OriginalCurrency,
  OriginalCurrencyDesc,
  ProviderCodeEncrypted,
  ProviderContractNo,
  ReferenceNo,
  Role,
  RoleDesc,
  BilledAmount,
  BoardResolutionFlag,
  BoardResolutionFlagDesc,
  CancellationDate,
  CardReferenceCode,
  ChargedAmount,
  CreditLimit,
  CreditPurpose,
  CreditPurposeDesc,
  FinancedAmount,
  FirstPaymentDate,
  FlagCardUsed,
  HolderLiability,
  HolderLiabilityDesc,
  InstallmentType,
  InstallmentTypeDesc,
  InstallmentsNumber,
  LastChargeDate,
  LastPaymentAmount,
  LastPaymentDate,
  MinPaymentIndicator,
  MinPaymentIndicatorDesc,
  MinPaymentPercentage,
  MonthlyPaymentAmount,
  NextPayment,
  NextPaymentDate,
  OutstandingBalance,
  OutstandingBalanceUnbilled,
  OutstandingPaymentsNumber,
  OverallCreditLimit,
  OverdueDays,
  OverdueDaysDesc,
  OverduePaymentsAmount,
  OverduePaymentsNumber,
  PaymentMethod,
  PaymentMethodDesc,
  PaymentPeriodicity,
  PaymentPeriodicityDesc,
  PremiumCard,
  PremiumCardDesc,
  ReorganizedCreditCode,
  ReorganizedCreditCodeDesc,
  ServicesLinesNo,
  TimesCardUsed,
  TransactionType,
  TransactionTypeDesc,
  Utilization,
  LinkedSubject_CBSubjectCode,
  LinkedSubject_Name,
  LinkedSubject_Role,
  LinkedSubject_RoleDesc,
  Note_TypeDesc,
  Note_Text,
  Note_Type,
  run_date,
  NULL AS ContractRequestDate,
  'granted' AS source
FROM
  prj-prod-dataplatform.risk_credit_cic_data.granted_contracts

UNION ALL

-- Query for dfnongranted
SELECT
  digitalLoanAccountId,
  crifApplicationId,
  customerId,
  processEngineGuid,
  requestGuid,
  NULL AS ContractHistoryType,
  CBContractCode,
  NULL AS ContractEndDate,
  ContractPhase,
  ContractPhaseDesc,
  NULL AS ContractStartDate,
  NULL AS ContractStatus,
  NULL AS ContractStatusDesc,
  ContractType,
  ContractTypeDesc,
  NULL AS Currency,
  NULL AS CurrencyDesc,
  LastUpdateDate,
  NULL AS OriginalCurrency,
  NULL AS OriginalCurrencyDesc,
  ProviderCodeEncrypted,
  ProviderContractNo,
  ReferenceNo,
  Role,
  RoleDesc,
  NULL AS BilledAmount,
  NULL AS BoardResolutionFlag,
  NULL AS BoardResolutionFlagDesc,
  NULL AS CancellationDate,
  NULL AS CardReferenceCode,
  NULL AS ChargedAmount,
  CreditLimit,
  NULL AS CreditPurpose,
  NULL AS CreditPurposeDesc,
  FinancedAmount,
  NULL AS FirstPaymentDate,
  NULL AS FlagCardUsed,
  NULL AS HolderLiability,
  NULL AS HolderLiabilityDesc,
  NULL AS InstallmentType,
  NULL AS InstallmentTypeDesc,
  InstallmentsNumber,
  NULL AS LastChargeDate,
  NULL AS LastPaymentAmount,
  NULL AS LastPaymentDate,
  NULL AS MinPaymentIndicator,
  NULL AS MinPaymentIndicatorDesc,
  NULL AS MinPaymentPercentage,
  MonthlyPaymentAmount,
  NULL AS NextPayment,
  NULL AS NextPaymentDate,
  NULL AS OutstandingBalance,
  NULL AS OutstandingBalanceUnbilled,
  NULL AS OutstandingPaymentsNumber,
  NULL AS OverallCreditLimit,
  NULL AS OverdueDays,
  NULL AS OverdueDaysDesc,
  NULL AS OverduePaymentsAmount,
  NULL AS OverduePaymentsNumber,
  NULL AS PaymentMethod,
  NULL AS PaymentMethodDesc,
  PaymentPeriodicity,
  PaymentPeriodicityDesc,
  NULL AS PremiumCard,
  NULL AS PremiumCardDesc,
  NULL AS ReorganizedCreditCode,
  NULL AS ReorganizedCreditCodeDesc,
  NULL AS ServicesLinesNo,
  NULL AS TimesCardUsed,
  NULL AS TransactionType,
  NULL AS TransactionTypeDesc,
  NULL AS Utilization,
  LinkedSubject_CBSubjectCode,
  LinkedSubject_Name,
  LinkedSubject_Role,
  LinkedSubject_RoleDesc,
  Note_TypeDesc,
  Note_Text,
  Note_Type,
  run_date,
  ContractRequestDate,
  'nongranted' AS source
FROM
  prj-prod-dataplatform.risk_credit_cic_data.notgranted_contracts

)
select gc.run_date, lmt.startApplyDateTime, lmt.disbursementDateTime 
, gc.digitalLoanAccountId
, gc.customerId
, count(distinct gc.CBContractCode) cnt_contracts
, count(distinct case when gc.ContractHistoryType like 'NonInstallments' then gc.CBContractCode end) ContractHistoryType_Noninstallments
, count(distinct case when gc.ContractHistoryType like 'Utilities' then gc.CBContractCode end) ContractHistoryType_Utilities
, count(distinct case when gc.ContractHistoryType like 'CreditCards' then gc.CBContractCode end) ContractHistoryType_CreditCards
, count(distinct case when gc.ContractHistoryType like 'Installments' then gc.CBContractCode end) ContractHistoryType_Installments
, count(distinct case when gc.ContractHistoryType not in ('CreditCards','NonInstallments', 'Utilities', 'Installments')  then gc.CBContractCode end)  ContractHistoryType_Null

, count(distinct case when gc.ContractHistoryType like 'NonInstallments' and gc.ContractPhaseDesc like 'Active' then gc.CBContractCode end) Noninstallments_Active
, count(distinct case when gc.ContractHistoryType like 'NonInstallments' and gc.ContractPhaseDesc like 'Closed in advance' then gc.CBContractCode end) Noninstallments_closedinadvance
, count(distinct case when gc.ContractHistoryType like 'NonInstallments' and gc.ContractPhaseDesc like 'Closed' then gc.CBContractCode end) Noninstallments_closed
, count(distinct case when gc.ContractHistoryType like 'NonInstallments' and gc.ContractPhaseDesc like 'Refused' then gc.CBContractCode end) Noninstallments_Refused
, count(distinct case when gc.ContractHistoryType like 'NonInstallments' and gc.ContractPhaseDesc like 'Renounced' then gc.CBContractCode end) Noninstallments_Renounced
, count(distinct case when gc.ContractHistoryType like 'NonInstallments' and gc.ContractPhaseDesc like 'Requested' then gc.CBContractCode end) Noninstallments_Renounced

, count(distinct case when gc.ContractHistoryType like 'Utilities' then gc.CBContractCode end) ContractHistoryType_Utilities

, count(distinct case when gc.ContractHistoryType like 'Utilities' and gc.ContractPhaseDesc like 'Active' then gc.CBContractCode end) Utilities_Active
, count(distinct case when gc.ContractHistoryType like 'Utilities' and gc.ContractPhaseDesc like 'Closed in advance' then gc.CBContractCode end) Utilities_closedinadvance
, count(distinct case when gc.ContractHistoryType like 'Utilities' and gc.ContractPhaseDesc like 'Closed' then gc.CBContractCode end) Utilities_closed
, count(distinct case when gc.ContractHistoryType like 'Utilities' and gc.ContractPhaseDesc like 'Refused' then gc.CBContractCode end) Utilities_Refused
, count(distinct case when gc.ContractHistoryType like 'Utilities' and gc.ContractPhaseDesc like 'Renounced' then gc.CBContractCode end) Utilities_Renounced
, count(distinct case when gc.ContractHistoryType like 'Utilities' and gc.ContractPhaseDesc like 'Requested' then gc.CBContractCode end) Utilities_Renounced

, count(distinct case when gc.ContractHistoryType like 'CreditCards' then gc.CBContractCode end) ContractHistoryType_CreditCards

, count(distinct case when gc.ContractHistoryType like 'CreditCards' and gc.ContractPhaseDesc like 'Active' then gc.CBContractCode end) CreditCards_Active
, count(distinct case when gc.ContractHistoryType like 'CreditCards' and gc.ContractPhaseDesc like 'Closed in advance' then gc.CBContractCode end) CreditCards_closedinadvance
, count(distinct case when gc.ContractHistoryType like 'CreditCards' and gc.ContractPhaseDesc like 'Closed' then gc.CBContractCode end) CreditCards_closed
, count(distinct case when gc.ContractHistoryType like 'CreditCards' and gc.ContractPhaseDesc like 'Refused' then gc.CBContractCode end) CreditCards_Refused
, count(distinct case when gc.ContractHistoryType like 'CreditCards' and gc.ContractPhaseDesc like 'Renounced' then gc.CBContractCode end) CreditCards_Renounced
, count(distinct case when gc.ContractHistoryType like 'CreditCards' and gc.ContractPhaseDesc like 'Requested' then gc.CBContractCode end) CreditCards_Renounced

, count(distinct case when gc.ContractHistoryType like 'Installments' then gc.CBContractCode end) ContractHistoryType_Installments

, count(distinct case when gc.ContractHistoryType like 'Installments' and gc.ContractPhaseDesc like 'Active' then gc.CBContractCode end) Installments_Active
, count(distinct case when gc.ContractHistoryType like 'Installments' and gc.ContractPhaseDesc like 'Closed in advance' then gc.CBContractCode end) Installments_closedinadvance
, count(distinct case when gc.ContractHistoryType like 'Installments' and gc.ContractPhaseDesc like 'Closed' then gc.CBContractCode end) Installments_closed
, count(distinct case when gc.ContractHistoryType like 'Installments' and gc.ContractPhaseDesc like 'Refused' then gc.CBContractCode end) Installments_Refused
, count(distinct case when gc.ContractHistoryType like 'Installments' and gc.ContractPhaseDesc like 'Renounced' then gc.CBContractCode end) Installments_Renounced
, count(distinct case when gc.ContractHistoryType like 'Installments' and gc.ContractPhaseDesc like 'Requested' then gc.CBContractCode end) Installments_Renounced

, count(distinct case when gc.ContractHistoryType not in ('CreditCards','NonInstallments', 'Utilities', 'Installments')  then gc.CBContractCode end)  ContractHistoryType_Null

, count(distinct case when gc.ContractHistoryType not in ('CreditCards','NonInstallments', 'Utilities', 'Installments') and gc.ContractPhaseDesc like 'Active' then gc.CBContractCode end) NA_Active
, count(distinct case when gc.ContractHistoryType not in ('CreditCards','NonInstallments', 'Utilities', 'Installments') and gc.ContractPhaseDesc like 'Closed in advance' then gc.CBContractCode end) NA_closedinadvance
, count(distinct case when gc.ContractHistoryType not in ('CreditCards','NonInstallments', 'Utilities', 'Installments') and gc.ContractPhaseDesc like 'Closed' then gc.CBContractCode end) NA_closed
, count(distinct case when gc.ContractHistoryType not in ('CreditCards','NonInstallments', 'Utilities', 'Installments') and gc.ContractPhaseDesc like 'Refused' then gc.CBContractCode end) NA_Refused
, count(distinct case when gc.ContractHistoryType not in ('CreditCards','NonInstallments', 'Utilities', 'Installments') and gc.ContractPhaseDesc like 'Renounced' then gc.CBContractCode end) NA_Renounced
, count(distinct case when gc.ContractHistoryType not in ('CreditCards','NonInstallments', 'Utilities', 'Installments') and gc.ContractPhaseDesc like 'Requested' then gc.CBContractCode end) NA_Renounced

, count(distinct case when gc.ContractPhaseDesc like 'Active' then gc.CBContractCode end) ContractPhaseDesc_Active
, count(distinct case when gc.ContractPhaseDesc like 'Closed in advance' then gc.CBContractCode end) ContractPhaseDesc_Closedinadvance
, count(distinct case when gc.ContractPhaseDesc like 'Closed' then gc.CBContractCode end) ContractPhaseDesc_Closed
, count(distinct case when gc.ContractPhaseDesc like 'Refused' then gc.CBContractCode end) ContractPhaseDesc_Refused
, count(distinct case when gc.ContractPhaseDesc like 'Renounced' then gc.CBContractCode end) ContractPhaseDesc_Renounced
, count(distinct case when gc.ContractPhaseDesc like 'Requested' then gc.CBContractCode end) ContractPhaseDesc_Requested

, COUNT(DISTINCT CASE WHEN gc.ContractStatusDesc LIKE 'Debt Assumption' THEN gc.CBContractCode END) AS ContractStatusDesc_DA,
  COUNT(DISTINCT CASE WHEN gc.ContractStatusDesc LIKE 'Write-off and Fully Settled' THEN gc.CBContractCode END) AS ContractStatusDesc_WOAFS,
  COUNT(DISTINCT CASE WHEN gc.ContractStatusDesc LIKE 'Under litigation / Delinquent' THEN gc.CBContractCode END) AS ContractStatusDesc_ULD,
  COUNT(DISTINCT CASE WHEN gc.ContractStatusDesc LIKE 'Blocked by the Bank due to fraud' THEN gc.CBContractCode END) AS ContractStatusDesc_BBTBDTF,
  COUNT(DISTINCT CASE WHEN gc.ContractStatusDesc LIKE 'Past Due' THEN gc.CBContractCode END) AS ContractStatusDesc_PD,
  COUNT(DISTINCT CASE WHEN gc.ContractStatusDesc LIKE 'Under dispute / non performing' THEN gc.CBContractCode END) AS ContractStatusDesc_UDNP,
  COUNT(DISTINCT CASE WHEN gc.ContractStatusDesc LIKE 'Repossessed' THEN gc.CBContractCode END) AS ContractStatusDesc_R,
  COUNT(DISTINCT CASE WHEN gc.ContractStatusDesc LIKE 'Blocked by the Bank due to card lost/stolen' THEN gc.CBContractCode END) AS ContractStatusDesc_BBTBDTCLS,
  COUNT(DISTINCT CASE WHEN gc.ContractStatusDesc LIKE 'Write-off and Credit transferred to third party / Collection' THEN gc.CBContractCode END) AS ContractStatusDesc_WOACTTTTPC,
  COUNT(DISTINCT CASE WHEN gc.ContractStatusDesc LIKE 'Previous delinquency settled' THEN gc.CBContractCode END) AS ContractStatusDesc_PDS,
  COUNT(DISTINCT CASE WHEN gc.ContractStatusDesc LIKE 'Pre-Activated' THEN gc.CBContractCode END) AS ContractStatusDesc_PA,
  COUNT(DISTINCT CASE WHEN gc.ContractStatusDesc LIKE 'Blocked or Closed voluntary by the Customer' THEN gc.CBContractCode END) AS ContractStatusDesc_BOCVBTC,
  COUNT(DISTINCT CASE WHEN gc.ContractStatusDesc LIKE 'There are unpaid amounts, Negotiated Settlement' THEN gc.CBContractCode END) AS ContractStatusDesc_TAUANS,
  COUNT(DISTINCT CASE WHEN gc.ContractStatusDesc LIKE 'Write-off (BLW)' THEN gc.CBContractCode END) AS ContractStatusDesc_WOBLW,
  COUNT(DISTINCT CASE WHEN gc.ContractStatusDesc LIKE 'Blocked by the Bank due to Credit Reasons' THEN gc.CBContractCode END) AS ContractStatusDesc_BBTBDTCR,
  COUNT(DISTINCT CASE WHEN gc.ContractStatusDesc LIKE 'Foreclosure' THEN gc.CBContractCode END) AS ContractStatusDesc_Foreclosure,
  COUNT(DISTINCT CASE WHEN gc.ContractStatusDesc LIKE 'Dispute / Litigation contested' THEN gc.CBContractCode END) AS ContractStatusDesc_DLC,
  COUNT(DISTINCT CASE WHEN gc.ContractStatusDesc LIKE 'Blocked or Closed due to Restructuring' THEN gc.CBContractCode END) AS ContractStatusDesc_BOCDR,
  COUNT(DISTINCT CASE WHEN COALESCE(gc.ContractStatusDesc, 'NA') = 'NA' THEN gc.CBContractCode END) AS ContractStatusDesc_NA,

  -- ContractTypeDesc counts
  COUNT(DISTINCT CASE WHEN gc.ContractTypeDesc LIKE 'Agricultural Loan' THEN gc.CBContractCode END) AS ContractTypeDesc_AL,
  COUNT(DISTINCT CASE WHEN gc.ContractTypeDesc LIKE 'Benefit Loan' THEN gc.CBContractCode END) AS ContractTypeDesc_BL,
  COUNT(DISTINCT CASE WHEN gc.ContractTypeDesc LIKE 'SWAP Loan' THEN gc.CBContractCode END) AS ContractTypeDesc_SL,
  COUNT(DISTINCT CASE WHEN gc.ContractTypeDesc LIKE 'Credit Line' THEN gc.CBContractCode END) AS ContractTypeDesc_CL,
  COUNT(DISTINCT CASE WHEN gc.ContractTypeDesc LIKE 'Vehicle leasing' THEN gc.CBContractCode END) AS ContractTypeDesc_VL,
  COUNT(DISTINCT CASE WHEN gc.ContractTypeDesc LIKE 'Internet' THEN gc.CBContractCode END) AS ContractTypeDesc_I,
  COUNT(DISTINCT CASE WHEN gc.ContractTypeDesc LIKE 'Term Loan' THEN gc.CBContractCode END) AS ContractTypeDesc_TL,
  COUNT(DISTINCT CASE WHEN gc.ContractTypeDesc LIKE 'Real estate leasing' THEN gc.CBContractCode END) AS ContractTypeDesc_REL,
  COUNT(DISTINCT CASE WHEN gc.ContractTypeDesc LIKE 'L/C' THEN gc.CBContractCode END) AS ContractTypeDesc_LC,
  COUNT(DISTINCT CASE WHEN gc.ContractTypeDesc LIKE 'Student Loan' THEN gc.CBContractCode END) AS ContractTypeDesc_STL,
  COUNT(DISTINCT CASE WHEN gc.ContractTypeDesc LIKE 'Domestic Bills Purchased â€" Case to Case' THEN gc.CBContractCode END) AS ContractTypeDesc_DBPCTC,
  COUNT(DISTINCT CASE WHEN gc.ContractTypeDesc LIKE 'Business Loan' THEN gc.CBContractCode END) AS ContractTypeDesc_BUL,
  COUNT(DISTINCT CASE WHEN gc.ContractTypeDesc LIKE 'Short Term Loan' THEN gc.CBContractCode END) AS ContractTypeDesc_STL,
  COUNT(DISTINCT CASE WHEN gc.ContractTypeDesc LIKE 'Loan Line' THEN gc.CBContractCode END) AS ContractTypeDesc_LL,
  COUNT(DISTINCT CASE WHEN gc.ContractTypeDesc LIKE 'Credit Card - MultiCurrency' THEN gc.CBContractCode END) AS ContractTypeDesc_CCMC,
  COUNT(DISTINCT CASE WHEN gc.ContractTypeDesc LIKE 'APEX Loan' THEN gc.CBContractCode END) AS ContractTypeDesc_AL,
  COUNT(DISTINCT CASE WHEN gc.ContractTypeDesc LIKE 'Commercial Paper Purchased' THEN gc.CBContractCode END) AS ContractTypeDesc_CPP,
  COUNT(DISTINCT CASE WHEN gc.ContractTypeDesc LIKE 'Equipment leasing' THEN gc.CBContractCode END) AS ContractTypeDesc_EL,
  COUNT(DISTINCT CASE WHEN gc.ContractTypeDesc LIKE 'Money Market' THEN gc.CBContractCode END) AS ContractTypeDesc_MM,
  COUNT(DISTINCT CASE WHEN gc.ContractTypeDesc LIKE 'Policy Loan' THEN gc.CBContractCode END) AS ContractTypeDesc_PL,
  COUNT(DISTINCT CASE WHEN gc.ContractTypeDesc LIKE 'Home equity loan' THEN gc.CBContractCode END) AS ContractTypeDesc_HEL,
  COUNT(DISTINCT CASE WHEN gc.ContractTypeDesc LIKE 'Salary loan' THEN gc.CBContractCode END) AS ContractTypeDesc_SL,
  COUNT(DISTINCT CASE WHEN gc.ContractTypeDesc LIKE 'Vehicle Loan' THEN gc.CBContractCode END) AS ContractTypeDesc_VL,
  COUNT(DISTINCT CASE WHEN gc.ContractTypeDesc LIKE 'Time Loan' THEN gc.CBContractCode END) AS ContractTypeDesc_TIL,
  COUNT(DISTINCT CASE WHEN gc.ContractTypeDesc LIKE 'Mobile telephony' THEN gc.CBContractCode END) AS ContractTypeDesc_MT,
  COUNT(DISTINCT CASE WHEN gc.ContractTypeDesc LIKE 'Credit Card - Shared Limit' THEN gc.CBContractCode END) AS ContractTypeDesc_CCSL,
  COUNT(DISTINCT CASE WHEN gc.ContractTypeDesc LIKE 'Personal Loan' THEN gc.CBContractCode END) AS ContractTypeDesc_PEL,
  COUNT(DISTINCT CASE WHEN gc.ContractTypeDesc LIKE 'Trust Loan' THEN gc.CBContractCode END) AS ContractTypeDesc_TRL,
  COUNT(DISTINCT CASE WHEN gc.ContractTypeDesc LIKE 'Unsecured loan' THEN gc.CBContractCode END) AS ContractTypeDesc_UL,
  COUNT(DISTINCT CASE WHEN gc.ContractTypeDesc LIKE 'Provident Loan' THEN gc.CBContractCode END) AS ContractTypeDesc_PRL,
  COUNT(DISTINCT CASE WHEN gc.ContractTypeDesc LIKE 'Credit Card' THEN gc.CBContractCode END) AS ContractTypeDesc_CC,
  COUNT(DISTINCT CASE WHEN gc.ContractTypeDesc LIKE 'Revolving Credit' THEN gc.CBContractCode END) AS ContractTypeDesc_RC,
  COUNT(DISTINCT CASE WHEN gc.ContractTypeDesc LIKE 'Mortgage/Real Estate' THEN gc.CBContractCode END) AS ContractTypeDesc_MRE,
  COUNT(DISTINCT CASE WHEN gc.ContractTypeDesc LIKE 'Insurance - Life Insurance' THEN gc.CBContractCode END) AS ContractTypeDesc_ILI,
  COUNT(DISTINCT CASE WHEN gc.ContractTypeDesc LIKE 'Omnibus Line' THEN gc.CBContractCode END) AS ContractTypeDesc_OL,
  COUNT(DISTINCT CASE WHEN COALESCE(gc.ContractTypeDesc, 'NA') = 'NA' THEN gc.CBContractCode END) AS ContractTypeDesc_NA,
  count(distinct ProviderCodeEncrypted) distinctprovidercounts,

  -- RoleDesc counts
  COUNT(DISTINCT CASE WHEN gc.RoleDesc LIKE 'Guarantor/Surety' THEN gc.CBContractCode END) AS RoleDesc_GuarantorSurety,
  COUNT(DISTINCT CASE WHEN gc.RoleDesc LIKE 'Co-Borrower' THEN gc.CBContractCode END) AS RoleDesc_CoBorrower,
  COUNT(DISTINCT CASE WHEN gc.RoleDesc LIKE 'Borrower' THEN gc.CBContractCode END) AS RoleDesc_Borrower,
  COUNT(DISTINCT CASE WHEN COALESCE(gc.RoleDesc, 'NA') = 'NA' THEN gc.CBContractCode END) AS RoleDesc_NA,

-- CreditPurposeDesc counts
  COUNT(DISTINCT CASE WHEN gc.CreditPurposeDesc LIKE 'Development Loan Incentives - Socialized Low Cost Housing (Loans to individuals for housing purposes )' THEN gc.CBContractCode END) AS CreditPurposeDesc_DLI_SLCH_Individual,
  COUNT(DISTINCT CASE WHEN gc.CreditPurposeDesc LIKE 'Loan to Government - GOCCs (Other Financial)' THEN gc.CBContractCode END) AS CreditPurposeDesc_LTG_GOCCs_OF,
  COUNT(DISTINCT CASE WHEN gc.CreditPurposeDesc LIKE 'Loan to Government - GOCCs (Social Security Institutions)' THEN gc.CBContractCode END) AS CreditPurposeDesc_LTG_GOCCs_SSI,
  COUNT(DISTINCT CASE WHEN gc.CreditPurposeDesc LIKE 'Loans to Private Corporation (Non-Financial)' THEN gc.CBContractCode END) AS CreditPurposeDesc_LPC_NonFinancial,
  COUNT(DISTINCT CASE WHEN gc.CreditPurposeDesc LIKE 'Agrarian Reform' THEN gc.CBContractCode END) AS CreditPurposeDesc_AgrarianReform,
  COUNT(DISTINCT CASE WHEN gc.CreditPurposeDesc LIKE 'Microfinance Loans' THEN gc.CBContractCode END) AS CreditPurposeDesc_MicrofinanceLoans,
  COUNT(DISTINCT CASE WHEN gc.CreditPurposeDesc LIKE 'Development Loan Incentives - Educational Inst.' THEN gc.CBContractCode END) AS CreditPurposeDesc_DLI_EducationalInst,
  COUNT(DISTINCT CASE WHEN gc.CreditPurposeDesc LIKE 'Loans to Individual for other purposes' THEN gc.CBContractCode END) AS CreditPurposeDesc_LI_OtherPurposes,
  COUNT(DISTINCT CASE WHEN gc.CreditPurposeDesc LIKE 'Loan to Government - National Government' THEN gc.CBContractCode END) AS CreditPurposeDesc_LTG_NationalGovt,
  COUNT(DISTINCT CASE WHEN gc.CreditPurposeDesc LIKE 'Other Agricultural Credit' THEN gc.CBContractCode END) AS CreditPurposeDesc_OtherAgriculturalCredit,
  COUNT(DISTINCT CASE WHEN gc.CreditPurposeDesc LIKE 'Development Loan Incentives - Cooperatives' THEN gc.CBContractCode END) AS CreditPurposeDesc_DLI_Cooperatives,
  COUNT(DISTINCT CASE WHEN gc.CreditPurposeDesc LIKE 'Small and Medium Enterprise Loans (Small Scale Enterprise)' THEN gc.CBContractCode END) AS CreditPurposeDesc_SME_SmallScale,
  COUNT(DISTINCT CASE WHEN gc.CreditPurposeDesc LIKE 'Loans to Private Corporation (Financial)' THEN gc.CBContractCode END) AS CreditPurposeDesc_LPC_Financial,
  COUNT(DISTINCT CASE WHEN gc.CreditPurposeDesc LIKE 'Contract to Sell' THEN gc.CBContractCode END) AS CreditPurposeDesc_ContractToSell,
  COUNT(DISTINCT CASE WHEN gc.CreditPurposeDesc LIKE 'Loan to Government - LGUs' THEN gc.CBContractCode END) AS CreditPurposeDesc_LTG_LGUs,
  COUNT(DISTINCT CASE WHEN gc.CreditPurposeDesc LIKE 'Loans to Individual for Consumption Purposes - Auto Loans' THEN gc.CBContractCode END) AS CreditPurposeDesc_LI_Consumption_AutoLoans,
  COUNT(DISTINCT CASE WHEN gc.CreditPurposeDesc LIKE 'Loans to Individual for Consumption Purposes - Others' THEN gc.CBContractCode END) AS CreditPurposeDesc_LI_Consumption_Others,
  COUNT(DISTINCT CASE WHEN gc.CreditPurposeDesc LIKE 'Development Loan Incentives - Socialized Low Cost Housing (Others)' THEN gc.CBContractCode END) AS CreditPurposeDesc_DLI_SLCH_Others,
  COUNT(DISTINCT CASE WHEN gc.CreditPurposeDesc LIKE 'Small and Medium Enterprise Loans (Medium Scale Enterprise)' THEN gc.CBContractCode END) AS CreditPurposeDesc_SME_MediumScale,
  COUNT(DISTINCT CASE WHEN COALESCE(gc.CreditPurposeDesc, 'NA') = 'NA' THEN gc.CBContractCode END) AS CreditPurposeDesc_NA,
sum(cast(coalesce(gc.FinancedAmount, '0') as numeric)) totalFinanceAmount,
max(cast(gc.FinancedAmount as numeric)) maxFinanceAmount,
min(cast(gc.FinancedAmount as numeric)) minFinanceAmount,
min(gc.FirstPaymentDate) min_FirstPaymentDate,
max(gc.FirstPaymentDate) max_FirstPaymentDate,
sum(cast(coalesce(FlagCardUsed, '0') as numeric)) flagCardUsed_count 
from  base gc
left join`risk_credit_mis.loan_master_table` lmt on lmt.digitalLoanAccountId = gc.digitalLoanAccountId
group by 1,2,3,4,5
order by customerId, startApplyDateTime, disbursementDateTime, run_date"""

df = client.query(sq).to_dataframe(progress_bar_type='tqdm')
# Out:
# Job ID ee5c8f4b-5209-4caa-9276-9db18a5b7c86 successfully executed: |          |
# Downloading: 100%|██████████|

# %%
df.columns.values
# Out:
# array(['run_date', 'startApplyDateTime', 'disbursementDateTime',
#        'digitalLoanAccountId', 'customerId', 'cnt_contracts',
#        'ContractHistoryType_Noninstallments',
#        'ContractHistoryType_Utilities', 'ContractHistoryType_CreditCards',
#        'ContractHistoryType_Installments', 'ContractHistoryType_Null',
#        'Noninstallments_Active', 'Noninstallments_closedinadvance',
#        'Noninstallments_closed', 'Noninstallments_Refused',
#        'Noninstallments_Renounced', 'Noninstallments_Renounced_1',
#        'ContractHistoryType_Utilities_1', 'Utilities_Active',
#        'Utilities_closedinadvance', 'Utilities_closed',
#        'Utilities_Refused', 'Utilities_Renounced',
#        'Utilities_Renounced_1', 'ContractHistoryType_CreditCards_1',
#        'CreditCards_Active', 'CreditCards_closedinadvance',
#        'CreditCards_closed', 'CreditCards_Refused',
#        'CreditCards_Renounced', 'CreditCards_Renounced_1',
# ...

# %%
pd.set_option("Display.max_columns", None)
df.sample(10)
# Out:
#           run_date  startApplyDateTime disbursementDateTime  \
# 98036   2023-12-12 2023-12-12 18:29:18                  NaT
# 193981  2024-07-05 2024-07-03 12:54:22                  NaT
# 160895  2024-06-04 2024-06-04 10:36:05                  NaT
# 170678  2024-06-14 2024-06-14 14:38:54                  NaT
# 141142  2024-04-23 2024-04-23 16:55:44  2024-04-23 17:08:39
# 96571   2023-10-11 2023-10-11 09:57:15                  NaT
# 175624  2024-06-18 2024-06-18 15:44:34                  NaT
# 71526   2023-07-20 2023-07-20 11:40:07                  NaT
# 31446   2023-02-16 2023-02-16 10:26:47                  NaT
# 127057  2024-02-25 2024-02-25 09:03:56                  NaT
#
#                         digitalLoanAccountId customerId  cnt_contracts  \
# 98036   65ad4ef1-071f-4862-9cee-dcfd1c61d6e4    2274944              7
# 193981  5e18bb3a-5b92-4566-ac61-d331968b7c07    2630062             10
# 160895  4f483e6e-815a-47bc-b698-b69b16e224df    2550730             14
# ...

# %%
df[['customerId', 'cnt_contracts', 'Noninstallments_Active', 'Utilities_Active', 'CreditCards_Active', 'Installments_Active', 'totalFinanceAmount']][df['totalFinanceAmount']==0]
# Out:
#        customerId  cnt_contracts  Noninstallments_Active  Utilities_Active  \
# 0         1000001              8                       0                 0
# 3         1000085             14                       0                 0
# 33        1000950             27                       1                 0
# 41        1001013              1                       1                 0
# 42        1001018              3                       0                 0
# ...           ...            ...                     ...               ...
# 218844    2687560              2                       0                 0
# 218849    2687583              1                       1                 0
# 218851    2687591              1                       0                 0
# 218855    2687618              1                       1                 0
# 218856    2687630              1                       0                 0
#
#         CreditCards_Active  Installments_Active totalFinanceAmount
# ...

# %%
df['run_date'].min()
# Out:
# datetime.date(2022, 10, 11)

# %%
df['run_date'].max()
# Out:
# datetime.date(2024, 7, 24)

# %%
sq = "select max(run_date) from prj-prod-dataplatform.risk_credit_cic_data.notgranted_contracts"
dfd = client.query(sq).to_dataframe()

# %%
dfd
# Out:
#           f0_
# 0  2024-07-24

# %%
sq = """select disbursementDateTime from risk_credit_mis.loan_master_table where new_loan_type like '%SIL%"""
